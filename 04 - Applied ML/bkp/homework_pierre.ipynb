# %% [markdown]
# ## Applied Machine Learning

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.learning_curve import learning_curve
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn import preprocessing

import matplotlib.pyplot as plt
plt.style.use('ggplot')
pd.options.mode.chained_assignment = None  # default='warn'
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Data

# %%
path = 'CrowdstormingDataJuly1st.csv'
raw_data  = pd.read_csv(path)
print(raw_data .shape)
raw_data.T
# Out:
# (146028, 28)
#                              0                1             2       \
# playerShort           lucas-wilchez       john-utaka   abdon-prats
# player                Lucas Wilchez       John Utaka   Abdón Prats
# club                  Real Zaragoza  Montpellier HSC  RCD Mallorca
# leagueCountry                 Spain           France         Spain
# birthday                 31.08.1983       08.01.1982    17.12.1992
# height                          177              179           181
# weight                           72               82            79
# position       Attacking Midfielder     Right Winger           NaN
# games                             1                1             1
# victories                         0                0             0
# ties                              0                0             1
# defeats                           1                1             0
# goals                             0                0             0
# yellowCards                       0                1             1
# yellowReds                        0                0             0
# redCards                          0                0             0
# photoID                   95212.jpg         1663.jpg           NaN
# rater1                         0.25             0.75           NaN
# rater2                          0.5             0.75           NaN
# refNum                            1                2             3
# refCountry                        1                2             3
# Alpha_3                         GRC              ZMB           ESP
# meanIAT                    0.326391         0.203375      0.369894
# nIAT                            712               40          1785
# seIAT                   0.000564112        0.0108749    0.00022949
# meanExp                       0.396        -0.204082      0.588297
# nExp                            750               49          1897
# seExp                    0.00269649        0.0615044    0.00100165
#
#                      3                 4             5       \
# playerShort      pablo-mari        ruben-pena  aaron-hughes
# player           Pablo Marí        Rubén Peña  Aaron Hughes
# club           RCD Mallorca   Real Valladolid     Fulham FC
# leagueCountry         Spain             Spain       England
# birthday         31.08.1993        18.07.1991    08.11.1979
# height                  191               172           182
# weight                   87                70            71
# position        Center Back  Right Midfielder   Center Back
# games                     1                 1             1
# victories                 1                 1             0
# ties                      0                 0             0
# defeats                   0                 0             1
# goals                     0                 0             0
# yellowCards               0                 0             0
# yellowReds                0                 0             0
# redCards                  0                 0             0
# photoID                 NaN               NaN      3868.jpg
# rater1                  NaN               NaN          0.25
# rater2                  NaN               NaN             0
# refNum                    3                 3             4
# refCountry                3                 3             4
# Alpha_3                 ESP               ESP           LUX
# meanIAT            0.369894          0.369894      0.325185
# nIAT                   1785              1785           127
# seIAT            0.00022949        0.00022949    0.00329681
# meanExp            0.588297          0.588297      0.538462
# nExp                   1897              1897           130
# seExp            0.00100165        0.00100165     0.0137522
#
#                            6                     7                  8       \
# playerShort    aleksandar-kolarov      alexander-tettey  anders-lindegaard
# player         Aleksandar Kolarov      Alexander Tettey  Anders Lindegaard
# club              Manchester City          Norwich City  Manchester United
# leagueCountry             England               England            England
# birthday               10.11.1985            04.04.1986         13.04.1984
# height                        187                   180                193
# weight                         80                    68                 80
# position            Left Fullback  Defensive Midfielder         Goalkeeper
# games                           1                     1                  1
# victories                       1                     0                  0
# ties                            0                     0                  1
# defeats                         0                     1                  0
# goals                           0                     0                  0
# yellowCards                     0                     0                  0
# yellowReds                      0                     0                  0
# redCards                        0                     0                  0
# photoID                 47704.jpg             22356.jpg          16528.jpg
# rater1                          0                     1               0.25
# rater2                       0.25                     1               0.25
# refNum                          4                     4                  4
# refCountry                      4                     4                  4
# Alpha_3                       LUX                   LUX                LUX
# meanIAT                  0.325185              0.325185           0.325185
# nIAT                          127                   127                127
# seIAT                  0.00329681            0.00329681         0.00329681
# meanExp                  0.538462              0.538462           0.538462
# nExp                          130                   130                130
# seExp                   0.0137522             0.0137522          0.0137522
#
#                         9            ...                    146018  \
# playerShort       andreas-beck       ...         slobodan-rajkovic
# player            Andreas Beck       ...         Slobodan Rajković
# club           1899 Hoffenheim       ...              Hamburger SV
# leagueCountry          Germany       ...                   Germany
# birthday            13.03.1987       ...                03.02.1989
# height                     180       ...                       191
# weight                      70       ...                        88
# position        Right Fullback       ...               Center Back
# games                        1       ...                         1
# victories                    1       ...                         1
# ties                         0       ...                         0
# defeats                      0       ...                         0
# goals                        0       ...                         0
# yellowCards                  0       ...                         0
# yellowReds                   0       ...                         0
# redCards                     0       ...                         0
# photoID              36499.jpg       ...                 37918.jpg
# rater1                       0       ...                         0
# rater2                       0       ...                         0
# refNum                       4       ...                      3147
# refCountry                   4       ...                        21
# Alpha_3                    LUX       ...                       HUN
# meanIAT               0.325185       ...                  0.376127
# nIAT                       127       ...                       574
# seIAT               0.00329681       ...               0.000714319
# meanExp               0.538462       ...                   0.49835
# nExp                       130       ...                       606
# seExp                0.0137522       ...                0.00296825
#
#                          146019                146020          146021  \
# playerShort       steven-taylor          timmy-simons   titus-bramble
# player            Steven Taylor          Timmy Simons   Titus Bramble
# club           Newcastle United        1. FC Nürnberg  Sunderland AFC
# leagueCountry           England               Germany         England
# birthday             23.01.1986            11.12.1976      21.07.1981
# height                      188                   186             187
# weight                       81                    79              87
# position                    NaN  Defensive Midfielder     Center Back
# games                         1                     1               1
# victories                     1                     1               1
# ties                          0                     0               0
# defeats                       0                     0               0
# goals                         0                     0               0
# yellowCards                   0                     0               0
# yellowReds                    0                     0               0
# redCards                      0                     0               0
# photoID               20602.jpg              1116.jpg        3872.jpg
# rater1                        0                     0            0.75
# rater2                     0.25                     0               1
# refNum                     3147                  3147            3147
# refCountry                   21                    21              21
# Alpha_3                     HUN                   HUN             HUN
# meanIAT                0.376127              0.376127        0.376127
# nIAT                        574                   574             574
# seIAT               0.000714319           0.000714319     0.000714319
# meanExp                 0.49835               0.49835         0.49835
# nExp                        606                   606             606
# seExp                0.00296825            0.00296825      0.00296825
#
#                              146022                146023           146024  \
# playerShort         tom-huddlestone         tomas-rosicky     winston-reid
# player              Tom Huddlestone         Tomáš Rosický     Winston Reid
# club              Tottenham Hotspur            Arsenal FC  West Ham United
# leagueCountry               England               England          England
# birthday                 28.12.1986            04.10.1980       03.07.1988
# height                          188                   178              190
# weight                           80                    67               87
# position       Defensive Midfielder  Attacking Midfielder      Center Back
# games                             1                     1                1
# victories                         0                     1                0
# ties                              1                     0                0
# defeats                           0                     0                1
# goals                             0                     1                0
# yellowCards                       0                     0                0
# yellowReds                        0                     0                0
# redCards                          0                     0                0
# photoID                   29395.jpg               444.jpg        53953.jpg
# rater1                          0.5                     0             0.25
# rater2                          0.5                     0              0.5
# refNum                         3147                  3147             3147
# refCountry                       21                    21               21
# Alpha_3                         HUN                   HUN              HUN
# meanIAT                    0.376127              0.376127         0.376127
# nIAT                            574                   574              574
# seIAT                   0.000714319           0.000714319      0.000714319
# meanExp                     0.49835               0.49835          0.49835
# nExp                            606                   606              606
# seExp                    0.00296825            0.00296825       0.00296825
#
#                         146025                146026           146027
# playerShort    xherdan-shaqiri   yassine-el-ghanassi     zdenk-pospch
# player         Xherdan Shaqiri   Yassine El Ghanassi   Zdeněk Pospěch
# club            Bayern München  West Bromwich Albion  1. FSV Mainz 05
# leagueCountry          Germany               England          Germany
# birthday            10.10.1991            12.07.1990       14.12.1978
# height                     169                   173              174
# weight                      72                   NaN               72
# position       Left Midfielder           Left Winger   Right Fullback
# games                        1                     1                1
# victories                    1                     0                0
# ties                         0                     0                0
# defeats                      0                     1                1
# goals                        0                     0                0
# yellowCards                  0                     0                0
# yellowReds                   0                     0                0
# redCards                     0                     0                0
# photoID             132744.jpg            129168.jpg        21828.jpg
# rater1                    0.25                   0.5                0
# rater2                    0.25                   0.5             0.25
# refNum                    3147                  3147             3147
# refCountry                  21                    21               21
# Alpha_3                    HUN                   HUN              HUN
# meanIAT               0.376127              0.376127         0.376127
# nIAT                       574                   574              574
# seIAT              0.000714319           0.000714319      0.000714319
# meanExp                0.49835               0.49835          0.49835
# nExp                       606                   606              606
# seExp               0.00296825            0.00296825       0.00296825
#
# [28 rows x 146028 columns]

# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this section we will try to do a first attempt at cleaning the data. A lot of missing values, strings and so on can be expected and we will treat them here before doing anything of it.
#
#
# It is quite a big dataframe. Are there duplicates in it?

# %%
raw_data[['playerShort', 'refNum']].duplicated().value_counts()
# Out:
# False    146028
# dtype: int64

# %% [markdown]
# The answer is no. Second, where are the missing values?

# %%
raw_data.count()
# Out:
# playerShort      146028
# player           146028
# club             146028
# leagueCountry    146028
# birthday         146028
# height           145765
# weight           143785
# position         128302
# games            146028
# victories        146028
# ties             146028
# defeats          146028
# goals            146028
# yellowCards      146028
# yellowReds       146028
# redCards         146028
# photoID          124621
# rater1           124621
# rater2           124621
# refNum           146028
# refCountry       146028
# Alpha_3          146027
# meanIAT          145865
# nIAT             145865
# seIAT            145865
# meanExp          145865
# nExp             145865
# seExp            145865
# dtype: int64

# %% [markdown]
# We remember that out ouf the 2053 players, only 1586 had photos available to rate. This is the reason the raters 1 and 2 have only 124621 values out of the 146028 dyads. We'll start by letting these go.

# %%
data = raw_data.dropna(how='all', subset=['rater1', 'rater2'])
data.shape[0]
# Out:
# 124621

# %% [markdown]
# Seeing the same value 124621, we know judges rated the exact same people.
#
# We can then parse the birthdate to keep only the year. The day and month will be meaningless, while mentalities may evolve over the years. Moreover, we can't keep strings as we won't be able to use them. We will drop the player, club columns right now (could try to map the club to a city, but it would be additional).  We drop the photoID because it is meaningless. The Alpha_3 column is the same as refCountry but in strings.

# %%
data["year"] = data["birthday"].apply(lambda x: pd.to_datetime(x).year)

# %%
data.drop(['player', 'club', 'photoID', 'birthday', 'Alpha_3'],axis=1, inplace=True)

# %% [markdown]
# ### Convert string values to float values where possible

# %% [markdown]
# We do not like loosing all string data, but our ML learning methods can't deal with non numeric values. In this subsection, we try to get something out of the strings.
#
# First, we split the "playerShort" column into First and Last names, and save the lengths to have a numeric value (I guess the length of a first/last name still gives an information we can use). We give IDs to countries and positions since there are only 4 countries and a dozen positions (and thus we can do that, as opposed to the clubs (there were like hundreds of them)). We merge the YellowRed and Red columns as they both describe a field exclusion.

# %%
data["firstname"] = pd.DataFrame(data["playerShort"].str.split('-').tolist())[0].apply(lambda x: len(str(x)))
data["lastname"] = pd.DataFrame(data["playerShort"].str.split('-').tolist())[1].apply(lambda x: len(str(x)))
data.drop(["playerShort"], axis=1, inplace=True)

# %%
#data.isnull().sum()

# %%
mapping_countries = {'England': 0, 'France': 1, 'Germany': 2, 'Spain': 3}

# %%
data.replace({'leagueCountry': mapping_countries}, inplace=True)

# %%
mapping_roles = {'Center Back': 0, 'Center Forward': 1, 'Defensive Midfielder': 2, 'Goalkeeper': 3, "Attacking Midfielder": 4,
                    "Left Fullback": 5, "Right Fullback" :6, "Left Midfielder" :7, "Right Winger" :8, "Center Midfielder" :9, 
                    "Right Midfielder": 10, "Left Winger" :11}
data.replace({'position': mapping_roles}, inplace=True)

# %% [markdown]
# Given the Standard Deviation is .1, it makes sense to have bins of width .25 (2 * .1 plus safety) and we can keep

# %%
clean_data = data.copy()

# %% [markdown]
# ## Processing the data

# %% [markdown]
# ### Skin color

# %% [markdown]
# We start by adding features since the 2 raters give different skin colors. We add the squared, cross and mean terms.

# %%
data["meanrating"] = clean_data[["rater2", "rater1"]].mean(axis=1)
data["rater1_squared"] = clean_data["rater1"]*2
data["rater2_squared"] = clean_data["rater2"]*2
data["cross_rates"] = clean_data["rater1"]*clean_data["rater2"]

# %% [markdown]
# ### Standardization

# %%
data = data.fillna(data.mean())

# %%
features = data.columns
x = data.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
std_data = pd.DataFrame(x_scaled, columns=features)

# %% [markdown]
# # Extract the labels

# %% [markdown]
# The objective of this section is to get which feature will be easier to predict. We keep the possibility of trusting only 1 rater instead of the two, since after all maybe the other one was drunk

# %%
focus_cols = ["rater1", "rater2", "rater1_squared", "rater2_squared", "cross_rates", "meanrating"]
std_data.corr().filter(focus_cols).drop(focus_cols).describe()
# Out:
#           rater1     rater2  rater1_squared  rater2_squared  cross_rates  \
# count  23.000000  23.000000       23.000000       23.000000    23.000000
# mean   -0.006575  -0.004941       -0.006575       -0.004941    -0.006575
# std     0.044192   0.042080        0.044192        0.042080     0.048553
# min    -0.133586  -0.135832       -0.133586       -0.135832    -0.160892
# 25%    -0.018643  -0.014856       -0.018643       -0.014856    -0.016890
# 50%     0.000958   0.000376        0.000958        0.000376    -0.000873
# 75%     0.009484   0.008963        0.009484        0.008963     0.013739
# max     0.066350   0.064943        0.066350        0.064943     0.069610
#
#        meanrating
# count   23.000000
# mean    -0.005875
# std      0.043710
# min     -0.137358
# 25%     -0.013924
# 50%      0.000681
# 75%      0.009406
# max      0.066943

# %% [markdown]
# It seems the better label would be the cross_rates, since it has maximal mean, minimum min and maximal max.

# %%
y = np.asarray(std_data['cross_rates'], dtype="|S6")
X = std_data.drop(focus_cols, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=4)

# %%
# STEP 2: train the model on the training set
# instantiate the model (using the default parameters)
rfc = RandomForestClassifier(n_jobs=-1)
# fit the model with data
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
def print_score(classifier, X_train, y_train, X_test, y_test):
    print('Train set score :', classifier.score(X_train, y_train))
    print('Test set score :', classifier.score(X_test, y_test))

# %%
print_score(rfc, X_train, y_train, X_test, y_test)
# Out:
# Train set score : 0.998381747178
# Test set score : 0.904812533852
